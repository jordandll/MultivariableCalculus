# %% [markdown]
# # Problem Set 4
# ## Part II
# #### Problem 1
#
# Let $f (u)$ be a function of one variable and let $F_c(x, t) = f (x − ct)$.
#
# **a)** Use the plotting feature of the mathlet to examine the graphs of $F_c$ in the cases
# $c = −1, 1, 2 $ for $f (u) = \cos^2 u$.
#
# Then for $c = 2$ make a sketch by hand of the graphs of the single-variable function
# $x \to F_2(x, t)$ for the values $t = −1, 0, 1$.

# %% [markdown]
# $$ F_{-1}(x,t) = \cos^2(x+t)$$

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi,np.pi,num=50)
xx, t = np.meshgrid(x,x)
F = np.cos(xx+t)**2
x = np.linspace(-np.pi,np.pi,num=200)
G = np.cos(x)**2
G1 = np.cos(x+1)**2
G2 = np.cos(x+2)**2

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(13,5))
ax1.set_xticks(np.linspace(-1,1,num=8)*np.pi, labels=[f'{i:.2f}' + r' $\pi$' for i in np.linspace(-1,1,num=8)])
ax1.grid()
ax1.set_xlabel('x-axis')
ax1.set_ylabel('F')
ax2.grid()
ax2.set_xlabel('x-axis')
ax2.set_ylabel('t-axis')


# ax1.plot_surface(x,t,F)
ax1.plot(x,G,label=r'$F_{-1}(x,0)$')
ax1.plot(x,G1,label=r'$F_{-1}(x,1)$')
ax1.plot(x,G2,label=r'$F_{-1}(x,2)$')
ax1.legend()
cs = ax2.contour(xx,t,F)
cb = fig.colorbar(cs)

# %% [markdown]
# $$ F_1(x,t) = \cos^2(x-t)$$

# %%
F = np.cos(xx-t)**2
G1 = np.cos(x-1)**2
G2 = np.cos(x-2)**2

fig, (ax1,ax2) = plt.subplots(1,2,figsize=(13,5))
ax1.grid()
ax1.set_xlabel('x-axis')
ax1.set_ylabel('F')
ax2.grid()
ax2.set_xlabel('x-axis')
ax2.set_ylabel('t-axis')


# ax1.plot_surface(x,t,F)
ax1.plot(x,G,label=r'$F_{1}(x,0)$')
ax1.plot(x,G1,label=r'$F_{1}(x,1)$')
ax1.plot(x,G2,label=r'$F_{1}(x,2)$')
ax1.legend()
cs = ax2.contour(xx,t,F)
cb = fig.colorbar(cs)

# %% [markdown]
# $$ F_2(x,t) = \cos^2(x-2t)$$

# %%
F = np.cos(xx-2*t)**2
G1 = np.cos(x-2)**2
G2 = np.cos(x-4)**2
H = np.cos(2*x)**2

fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2,figsize=(13,8))
ax1.grid()
ax1.set_xlabel('x-axis')
ax1.set_ylabel('F')
ax3.grid()
ax3.set_xlabel('t-axis')
ax3.set_ylabel('F')
ax2.grid()
ax2.set_xlabel('x-axis')
ax2.set_ylabel('t-axis')


# ax1.plot_surface(x,t,F)
ax1.plot(x,G,label=r'$F_{2}(x,0)$')
ax1.plot(x,G1,label=r'$F_{2}(x,1)$')
ax1.plot(x,G2,label=r'$F_{2}(x,2)$')
ax1.legend()
ax3.plot(x,H,label=r'$F_2(0,t)$')
ax3.legend()
cs = ax2.contour(xx,t,F)
cb = fig.colorbar(cs)

# %%
(np.pi,0.5*np.pi)
# Out:
# (3.141592653589793, 1.5707963267948966)

# %% [markdown]
# **b)** If the variable $t$ represents time, and $x$ the position on a one-dimensional string,
# and $f$ measures the displacement of the string perpendicular to the $x$-axis, what
# phenomenon is being described by the function $F_2(x, t)$?

# %% [markdown]
# $$ u = x - 2t \quad\quad f(u) = \cos^2 u = \quad\quad f'(u) -2\cos u \sin u$$

# %% [markdown]
# $$ f'(u) = -\sin 2u \quad\quad g(u):= 0.5\cos 2u \quad\quad g'(u) = f'(u) \quad\implies$$

# %% [markdown]
# $$ \cos ^2 u = 0.5\cos 2u + K$$

# %% [markdown]
# $$ K = \cos^2 0 - 0.5\cos 0 = 0.5$$

# %% [markdown]
# Thus,
#
# $$ f(u) = \cos^2 u = 0.5(\cos 2u + 1)$$

# %% [markdown]
# and,
#
# $$ F_2(x,t) = 0.5\big(1+\cos(2x - 4t)\big)$$

# %% [markdown]
# A traveling wave with a frequency $f_t$ and wavelength $\mathit{wl}_t$ in the time-domain of
#
# $$ f_t = \frac{2}{\pi} \quad\quad\text{and}\quad\quad \mathit{wl}_t = 0.5\pi$$

# %% [markdown]
# and a frequency $f_p$ and wavelength $\mathit{wl}_p$ in the space-domain or position-domain of
#
# $$ f_p = \frac{1}{\pi} \quad\quad\text{and}\quad\quad \mathit{wl}_p = \pi$$

# %% [markdown]
# The speed $s$ of the traveling wave is thus:
#
# $$ s = f_t\cdot\mathit{wl}_p = 2 = c$$

# %% [markdown]
# #### Problem 2
#
# **a)** Find the curve of intersection of the surfaces $z = x^2 − y^2$ and $z = 2 + (x − y)^2$
# in parametric form.

# %% [markdown]
# $$ (x-y)^2 - x^2 + y^2 + 2 = 0 \quad\implies\quad 2y^2 + 2 - 2xy = 0$$

# %% [markdown]
# $$ \implies\quad y + \frac{1}{y}  = x$$

# %% [markdown]
# $$ \mathbf{r}:=\mathbf{r}(t) = \langle t , t\rangle + \left\langle \frac{1}{t},0, \frac{1}{2t^2}+1-\frac{3t^2}{2}\right\rangle$$

# %% [markdown]
# $$ y := y(t) = t \quad\quad x:=x(t) = 0.5t + \frac{1}{2t}\quad\quad z:=z(t) = \left(t + \frac{1}{t} \right)^2- t^2$$

# %% [markdown]
# $$ z = z(t) = \frac{1}{t^2} + 2$$

# %%
t = sp.symbols('t')
r_x = t+1/(t); r_y = t
r_z = r_x**2 - r_y**2; r_z.expand()
# Out:
# 2 + t**(-2)

# %%
t = np.linspace(0.1,2,num=200)
y = t 
x = t + 1/(t)
z = x**2-y**2

fig, ax = plt.subplots(subplot_kw=dict(projection = '3d'))
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
ax.grid()

ax.plot(x,y,z)

# %% [markdown]
# **b)** Find the angle of intersection of these two surfaces at the point $(2, 1, 3)$.
# (The angle of intersection of two surfaces is defined to be the angle made by their
# tangent planes.)

# %% [markdown]
# $$ f(x,y):=z = x^2-y^2 \quad\quad \text{and}\quad\quad g(x,y):=z = 2 + (x-y)^2$$

# %% [markdown]
# $$ f_x = 2x \quad\quad f_y = -2y \quad\quad g_x = 2(x-y) \quad\quad g_y = 2(y-x)$$

# %% [markdown]
# The linear approximations of $f(x,y)$ and $g(x,y)$, denoted as $F_1(x,y)$ and $G_1(x,y)$ respectively, at $(2,1,3)$, are:
#
# $$ F_1(x,y) = 3 + f_x(2,1)(x-2) + f_y(2,1)(y-1) = 3 + 4x - 8 + 2y + 2 = 4x - 2y - 3$$

# %% [markdown]
# $$ G_1(x,y) = 3 + g_x(2,1)(x-2) + g_y(2,1)(y-1) = 3 + 2x - 4 - 2y + 2 = 2x - 2y + 1$$

# %% [markdown]
# The normals to the planes given by $F_1(x,y)$ and $G_1(x,y)$, denoted as $\mathbf{a}$ and $\mathbf{b}$ respectively, are:
#
# $$ \mathbf{a} = \langle 1, -f_x(2,1),-f_y(2,1)\rangle = \langle -4,2,1\rangle \quad\quad \mathbf{b} = \langle -2,2,1\rangle$$

# %% [markdown]
# Finally, the dihedral angle between the two tangent planes is given by:
#
# $$ \mathbf{a}\cdot\mathbf{b} = |\mathbf{a}||\mathbf{b}|\cos\theta \quad\implies\quad \theta = \arccos \frac{\mathbf{a}\cdot\mathbf{b}}{|\mathbf{a}||\mathbf{b}|}$$

# %% [markdown]
# $$\theta = \arccos \frac{1+8-4}{\sqrt{21\cdot9}} = \arccos \frac{5}{3\sqrt{21}} \approxeq 68.67^{\circ}$$

# %%
theta = np.arccos(5/(3*np.sqrt(21))); np.degrees(theta)
# Out:
# 68.67261591653461

# %% [markdown]
# **c)** Check that the tangent vector to the curve of intersection found in part(a) at the
# point $(2, 1, 3)$ lies in (i.e. is parallel to) the tangent plane of each of the two surfaces.

# %% [markdown]
# $$ \mathbf{T} := \mathbf{T}(t) = \frac{\mathbf{r}'(t)}{|\mathbf{r}'(t)|} $$

# %% [markdown]
# $$ \mathbf{T}\parallel \mathcal{P}_a \;\iff\; \mathbf{T} \perp \mathbf{a} \;\iff\; \mathbf{T}\cdot\mathbf{a} = 0$$

# %% [markdown]
# Here $\mathcal{P}_a$ is the plane given by $F_1(x,y)$ and is normal to $\mathbf{a}$.

# %% [markdown]
# At $(2,1,3)$, $t=1$.

# %% [markdown]
# $$\mathbf{r}'(1)\cdot\mathbf{a} = 2 - 2 = 0 \quad\therefore\quad \mathbf{T}(1)\cdot\mathbf{a} = 0$$

# %% [markdown]
# $$ \therefore\quad \mathbf{T}(1)\perp\mathbf{a} \quad\therefore\quad \mathbf{T}(1) \parallel \mathcal{P}_a$$

# %% [markdown]
# Q.E.D.

# %% [markdown]
# $$ \mathbf{r}'(t) = \langle r_x'(t),r_y'(t),r_z'(t)\rangle$$

# %%
r_x
# Out:
# t + 1/t

# %% [markdown]
# $$ r_x'(t) = 1 - \frac{1}{t^2}$$

# %% [markdown]
# $$ r_y'(t) = 1$$

# %%
r_z.expand()
# Out:
# 2 + t**(-2)

# %% [markdown]
# $$r_z'(t) = -\frac{2}{t^3}$$

# %% [markdown]
# Likewise
#
# $$ \mathbf{T}\parallel\mathcal{P}_b \;\iff\; \mathbf{T}\perp\mathbf{b} \;\iff\; \mathbf{T}\cdot\mathbf{b} = 0$$

# %% [markdown]
# Here $\mathcal{P}_b$ is the plane that is normal to $\mathbf{b}$ and is given by $G_1(x,y)$.

# %% [markdown]
# Recall that:
#
#  $$\mathbf{b} = \langle-2,2,1\rangle$$

# %% [markdown]
# $$ \mathbf{r}'(1)\cdot\mathbf{b} = 2-2 = 0 \quad\therefore \quad  \mathbf{T}(1)\parallel\mathcal{P}_b $$

# %% [markdown]
# #### Problem 3
# Let $\displaystyle f (x, y) = \frac{4}{1+x^2+y^2}$ and let $S$ be the surface given by the graph of $f (x, y)$.
#
# **a)** Make a sketch of the surface $S$ in $3$-space, and also a (separate) sketch of the
# contour plot of $f$.

# %%
x = np.linspace(-2,2,num=200)
X, Y = np.meshgrid(x,x)
f = 4/(1+X**2+Y**2)

t = x
r_2 = (t, 3/2-t**2)

r = (*r_2,16/(13-8*t**2+4*t**4))

fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')

ax.plot_surface(X,Y,f)
ax.plot(*r, label=r'$\mathbf{r}(t)$')
ax.plot(r[1], r[0], r[2], label=r'$\mathbf{r}^*(t)$')
ax.legend()

ax.annotate(r'$\max\mathbf{r}_2$', R(-1))
ax.annotate(r'$\min\mathbf{r}_2$', R(0))
ax.annotate(r'$\max\mathbf{r}_2$', R(1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 19
#      16 ax.plot(r[1], r[0], r[2], label=r'$\mathbf{r}^*(t)$')
#      17 ax.legend()
# ---> 19 ax.annotate(r'$\max\mathbf{r}_2$', R(-1))
#      20 ax.annotate(r'$\min\mathbf{r}_2$', R(0))
#      21 ax.annotate(r'$\max\mathbf{r}_2$', R(1))
#
# Cell In[28], line 2, in R(t)
#       1 def R(t):
# ----> 2     return tuple(t, 3/2-t**2, 16/(13-8*t**2+4*t**4))
#
# TypeError: tuple expected at most 1 argument, got 3

# %%
figc, axc = plt.subplots()
axc.set_xlabel('x-axis')
axc.set_ylabel('y-axis')

cs = axc.contour(X,Y,f,levels=12)
cb = figc.colorbar(cs)

axc.plot(*r_2, label = r'$\mathbf{r}_2(t)$')
axc.legend()

axc.annotate(r'$\max\mathbf{r}_2$', (R(-1)[0],R(-1)[1]))
axc.annotate(r'$\min\mathbf{r}_2$', (R(0)[0],R(0)[1]))
axc.annotate(r'$\max\mathbf{r}_2$', (R(1)[0],R(1)[1]))
# Out:
# Text(1, 0.5, '$\\max\\mathbf{r}_2$')

# %% [markdown]
# **b)** Let $C_2$ denote the curve in the $xy$-plane given by $\mathbf{r}_2(t) =\langle t, \frac{3}{2} − t^2\rangle$; and let $C$
# denote the curve on the surface $S$ which has $C_2$ as its shadow in the $xy$-plane. Find
# the parametric equations $\mathbf{r} = \mathbf{r}(t)$ for $C$.

# %% [markdown]
# $$\mathbf{r} = \langle *\mathbf{r}_2, f(\mathbf{r}_2)\rangle =\langle r_{2,x}, r_{2,y}, f(\mathbf{r}_2)\rangle$$

# %% [markdown]
# $$ f(\mathbf{r}_2) = \frac{4}{1+t^2 + r_{2,y}^2}$$

# %% [markdown]
# $$ r_{2,y}^2 = \left(\frac{3-2t^2}{2}\right)^2 = \frac{9 - 12t^2 + 4t^4}{4}$$

# %% [markdown]
# $$ 1 + t^2 + r_{2,y}^2 = \frac{4 + 4t^2 + 9 - 12t^2 + 4t^4}{4} = \frac{13 - 8t^2 + 4t^4}{4}$$

# %% [markdown]
# Thus,
#
# $$ f(\mathbf{r}_2) = \frac{16}{13-8t^2 + 4t^4}$$

# %% [markdown]
# **c)** Sketch $C$ in on the picture of $S$ of part(a), and also $C_2$ on the contour plot of
# part(a).

# %%
def R(t):
    return (t, 3/2-t**2, 16/(13-8*t**2+4*t**4))

# %% [markdown]
# **d)** Let $z(t)$ denote the $z$-component of the parametric equations $\mathbf{r} = \mathbf{r}(t)$ of $C$ found in part(b). Find the points where $z(t)$ has its local maxima and minima, and add these in to the sketch of part(a).

# %% [markdown]
# $$ z(t) = f(\mathbf{r}_2)$$

# %% [markdown]
# $$ z'(t) = -\frac{16\big(16t^3 - 16t\big)}{\big(13-8t^2+4t^4\big)^2}$$

# %% [markdown]
# $$ z(t_e) = 0 \quad\implies\quad 16t_e\big(t_e^2-1\big) = 0$$

# %% [markdown]
# $$ \implies\quad t_e = \{0,1,-1\}$$

# %% [markdown]
# The local min and max occur at:
#
# $$ z_\max = z(t_\max) = z(\pm 1) = \frac{16}{9} \quad\quad\text{and}\quad\quad z_\min = z(t_\min) = z(0) = \frac{16}{13}$$

# %%
(R(-1),R(0),R(1))
# Out:
# ((-1, 0.5, 1.7777777777777777),
#  (0, 1.5, 1.2307692307692308),
#  (1, 0.5, 1.7777777777777777))

# %% [markdown]
# **e)** Set up the function $h(t)$ which gives the square of the distance from the origin to
# a variable point on the curve $C_2$, and then find the local maxima and minima of $h(t)$.
# How do these points relate to the maxima and minima found in part(d), and why?

# %% [markdown]
# $$ h(t) = |\mathbf{r}_2|^2 = t^2 + \left(\frac{3}{2} - t^2\right)^2 = 3 - 2t^2 + t^4$$

# %% [markdown]
# $$ h'(t) = 4t^3 - 4t$$

# %% [markdown]
# $$ h'(t_e) = 0 \quad\implies\quad 4t_e\big(t_e^2-1) = 0$$

# %% [markdown]
# $$ \implies\quad t_e = \{0,1,-1\}$$

# %% [markdown]
# $$ h_\max = h(t_\max) = h(0) = 3 \quad\quad\text{and}\quad\quad h_\min = h(t_\min) = h(\pm 1) = 2$$

# %% [markdown]
# The critical points of both $h(t)$ and $z(t)$ occur at the same time $t_e=\{0,1,-1\}$, however, $t_\max$ and $t_\min$ are inverted for each function.  We could say there exists a duality between the min and max values of $h(t)$ and $z(t)$ with respect to the time at which each occurs.  As for why?

# %% [markdown]
# $$ z(t) = f(\mathbf{r}_2) = \frac{16}{1+h(t)}$$

# %% [markdown]
# $$ z'(t) = -\frac{16h'(t)}{\big(1+h(t)\big)^2}$$

# %% [markdown]
# $$ z'(t_e) = 0 \quad\implies\quad h'(t_e) = 0 \quad\implies\quad t_e = \{0,1,-1\}$$

# %% [markdown]
# #### Problem 4
# Suppose that three non-negative numbers are restricted by the condition that the
# sum of their squares is equal to $27$. Using critical point analysis, with 2nd derivative
# and/or boundary tests as needed, find the maximum and minimum values of the sum
# of their cubes.

# %% [markdown]
# \begin{equation}\tag{4.1}
#     x^2 + y^2 + z^2 = 27
# \end{equation}
