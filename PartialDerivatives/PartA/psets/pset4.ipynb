# %% [markdown]
# # Problem Set 4
#
# ## Part I
#
# ### Partial Differentiation
#
# ### Functions and Partial Derivatives

# %% [markdown]
# #### $\S\,2\mathrm{A} : 1$

# %% [markdown]
# **a)**  $$ f(x,y):=z=1-x-y$$

# %% [markdown]
# $$ g(x):= y = 1-x-z $$

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2,2,num=200)

fig, ax = plt.subplots()
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')

for z in range(-2,3):
    ax.plot(x,1-x-z,label=r'$z= ' + str(z) + r'$')
ax.legend()

# %%
y = np.linspace(-3,5,num=200)
x, y = np.meshgrid(x,y)
z = 1-x-y

fig, ax = plt.subplots()
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')

ax.contour(x,y,z,levels=list(range(-2,3)))

# %% [markdown]
# **c)**  Each level curve at $z=a$ is a circle of radius $\sqrt{a}$, where $a$ is a positive real number.  The trace of the graph in the $xy$ plane is a point at origin since the curve is tangent to said plane at said point (origin).  The curve in each other coordinate plane is a parabola given by:  $z=y^2$ in $yz$ plane, and $z=x^2$ in the $xz$ plane.

# %% [markdown]
# #### $\S\,2\mathrm{A} : 2$
#
# **a)**  $$ w_x = 3x^2y - 3y^2 \quad\quad \text{and}\quad\quad w_y = x^3 - 6xy + 4y$$

# %% [markdown]
# **b)**  $$ z_x = \frac{1}{y}\quad\quad\text{and}\quad\quad z_y = -\frac{x}{y^2}$$

# %% [markdown]
# **c)**  $$ z:=\sin(3x+2y)$$

# %% [markdown]
# $$z_x = 3\cos(3x+2y) \quad\quad\text{and}\quad\quad z_y = 2\cos(3x+2y) $$

# %% [markdown]
# **d)**  $$ z:=e^{x^2y}$$

# %% [markdown]
# $$ z_x = 2xye^{x^2y} \quad\quad\text{and}\quad\quad z_y = x^2e^{x^2y}$$

# %% [markdown]
# **e)**  $$ z_x = \log(2x+y) + \frac{2x}{2x+y}$$

# %% [markdown]
# $$ z_y = \frac{x}{2x+y}$$

# %% [markdown]
# **f)**  $$ w:=x^2z - 2yz^3$$

# %% [markdown]
# $$ w_x = 2xz \quad\quad w_y = -2z^3 \quad\quad w_z = x^2 - 6yz^2$$

# %% [markdown]
# #### $\S\,2\mathrm{A} : 3$
#
# **b)**  $$ f_x = \frac{1}{x+y} - \frac{x}{(x+y)^2}= \frac{y}{(x+y)^2}$$

# %% [markdown]
# $$ f_y = -\frac{x}{(x+y)^2}$$

# %% [markdown]
# $$ f_{xy} = \frac{1}{(x+y)^2} - 2\,\frac{y}{(x+y)^3} = \frac{x-y}{(x+y)^3}$$

# %% [markdown]
# $$ f_{yx} = -\frac{1}{(x+y)^2} + 2\,\frac{x}{(x+y)^3} = \frac{x-y}{(x+y)^3}$$

# %% [markdown]
# Via the above two equations and equivalence principle,
#
# $$ f_{xy} = f_{yx}$$

# %% [markdown]
# #### $\S\,2\mathrm{A} : 5$
#
# **a)**  $$ w_x = ae^{ax}\sin ay \quad\quad\text{and}\quad\quad w_y = ae^{ax}\cos ay$$

# %% [markdown]
# $$ w_{xx} = a^2e^{ax}\sin ay \quad\quad\text{and}\quad\quad w_{yy} = -a^2e^{ax}\sin ay$$

# %% [markdown]
# $$ w_{xx} = -w_{yy}$$

# %% [markdown]
# ### Tangent Plane; Linear Approximation

# %% [markdown]
# #### $\S\,2\mathrm{B} : 1$
#
# **a)**  $$ z = xy^2 \quad\quad z_x = y^2 \quad\quad z_y = 2xy$$

# %% [markdown]
# The linear approximation of $z$ at $\mathbf{a}=(1,1)$ is:
#
# $$ P_1 = 1 + (x-1) + 2(y-1) = x + 2y - 2$$

# %% [markdown]
# **b)**  $$ w_x = -\frac{y^2}{x^2} \quad\quad \text{and}\quad\quad w_y = 2\,\frac{y}{x}$$

# %% [markdown]
# $$ P_1(x,y) = 4+w_x(1,2)(x-1) + w_y(1,2)(y-2) = 4  - 4(x-1) + 4(y-2) $$

# %% [markdown]
# $$  = 4y-4x$$

# %% [markdown]
# #### $\S\,2\mathrm{B} : 2$
#
# **a)**
#
# $$ z = \sqrt{x^2 + y^2} \quad\quad z_x = \frac{x}{z} \quad\quad z_y = \frac{y}{z}$$

# %% [markdown]
# The linear appproximation of $z$ at $P_0$ is:
#
# $$ P_1 = z_0 + \frac{x_0}{z_0}\,\Delta x + \frac{y_0}{z_0}\,\Delta y$$

# %% [markdown]
# **b)**  The ray is given by:
#
# $$ \mathbf{r} := \mathbf{r}(t) = t\langle x_0,y_0,z_0\rangle \quad\quad\text{where } t \ge 0$$

# %% [markdown]
# Or,
#
# $$ x = tx_0 \quad\quad y = ty_0 \quad\quad z=tz_0 $$

# %% [markdown]
# Via the above parametric equations, the equation that gives our cone, and substitution,
#
# $$ tz_0 = \sqrt{t^2x_0^2 + t^2y_0^2} = t\sqrt{x_0^2 + y_0^2} \quad\implies\quad z_0 = \sqrt{x_0^2 + y_0^2}$$

# %% [markdown]
# Thus, our ray fits on the cone.

# %% [markdown]
# Now, let $P_1:=z$.
#
# $$ tz_0 - z_0 = \frac{x_0}{z_0}\,(tx_0-x_0) + \frac{y_0}{z_0}\,(ty_0-y_0)$$

# %% [markdown]
# $$ z_0^2(t-1) = x_0^2(t-1) + y_0^2(t-1)$$

# %% [markdown]
# Dividing throughout by $t-1$ gives and equation that is consistent with the equation that gives our cone.

# %% [markdown]
# #### $\S\, 2\mathrm{B} : 3$
#
# In general, the hypotenuse $w$ of a right triangle with legs of length $x$ and $y$ is given by:
#
# $$ w = \sqrt{x^2 + y^2}$$

# %% [markdown]
# $$ w_x = \frac{x}{\sqrt{x^2+y^2}} \quad\quad\text{and}\quad\quad w_y = \frac{y}{\sqrt{x^2+y^2}}$$

# %% [markdown]
# The linear approximation of $w$ at $\mathbf{a}=(3,4)$ is given by:
#
# $$ P_1 = 5 + w_x(3,4)(x-3) + w_y(3,4)(y-4) = 5 + \frac{3}{5}\,(x-3) + \frac{4}{5}\,(y-4)$$

# %% [markdown]
# $$ w \approxeq P_1 \quad\text{where } \mathbf{x} = (x,y)\approxeq \mathbf{a}$$

# %% [markdown]
# Subtracting throughout the above equation by $w(3,4)=w_0$ gives:
#
# $$ \Delta w \approxeq \frac{3\Delta x + 4\Delta y}{5}$$

# %% [markdown]
# Assuming $\Delta x = \Delta y = 0.01$,
#
# $$ \Delta w \approxeq \frac{7}{5}\,0.01 = \frac{7}{500}$$

# %%
7/500
# Out:
# 0.014

# %% [markdown]
# #### $\S\,2\mathrm{B} : 5$
#
# **a)**  $$ w := (x+y+2)^2 $$

# %% [markdown]
# $$ w_x = 2(x+y+2) \quad\quad \text{and}\quad\quad w_y = w_x$$

# %% [markdown]
# At $(0,0)$:
#
# $$ P_1(x,y) = 4 + 4x + 4y $$

# %% [markdown]
# At $(1,2)$:
#
# $$ P_1 = 25 + w_x(1,2)(x-1) + w_y(1,2)(y-2) = 25 + 10(x-1) + 10(y-2)$$

# %% [markdown]
# $$ = 10x + 10y-5$$

# %% [markdown]
# **b)**  $$ w = e^x\cos y \quad\quad w_x = e^x\cos y \quad\quad w_y = -e^x\sin y$$

# %% [markdown]
# At origin:
#
# $$ P_1 = 1 + x $$

# %% [markdown]
# At $(0,0.5\pi)$,
#
# $$ P_1 = -(y-0.5\pi) = 0.5\pi - y$$

# %% [markdown]
# #### $\S\,2\mathrm{B} : 6$
#
# In general, the volume $V$ of a cylinder of radius $r$ and height $h$ is given by:
#
# $$ V = V(r,h) = V(\mathbf{x}) = \pi r^2h \quad\quad\text{where }\mathbf{x} = (x_1,x_2) = (r,h)$$

# %% [markdown]
# The linear approximation of $V$ at $\mathbf{a}=(a_r,a_h)=(2,3)$ is given by:
#
# $$ P_1(r,h) =P_1(\mathbf{x}) = V(\mathbf{a}) + V_r(\mathbf{a})(r-2) + V_h(\mathbf{a})(h-3)$$

# %% [markdown]
# The partial derivatives of $V$ are:
#
# $$ V_r = 2\pi r h \quad\quad\text{and}\quad\quad V_h = \pi r^2$$

# %% [markdown]
# Thus,
#
# $$ P_1(r,h) = 12\pi + 12\pi(r-2) + 4\pi(h-3)$$

# %% [markdown]
# $$ P_1(r,h) = 12\pi r + 4\pi h-24\pi = 4\pi(3r + h - 6)$$

# %% [markdown]
# Now, the task is to find a reasonable square centered at $\mathbf{a}$ wherein $\Delta P_1 = P_1(r,h)-P_1(2,3) \le 0.1$.

# %% [markdown]
# $$ \Delta P_1 = P_1(r,h)-P_1(2,3) = 12\pi \Delta r + 4\pi \Delta h \le 0.1$$

# %% [markdown]
# where,
#
# $$ \Delta r = r-2 \quad\quad\text{and}\quad\quad \Delta h = h-3$$

# %% [markdown]
# Whereas it is a square we are looking for therefore
#
# $$ \Delta r = \Delta h$$

# %% [markdown]
# Thus,
#
# $$ 12\pi\Delta r + 4\pi \Delta r = 16\pi \Delta r \le 0.1$$

# %% [markdown]
# $$ \Delta r = \Delta h \le \frac{1}{160\pi}$$

# %% [markdown]
# #### $\S\,2\mathrm{B} : 9$

# %% [markdown]
# $$ w = x^2(y+1) \quad\quad\text{and}\quad\quad\mathbf{a} = (1,0)$$

# %% [markdown]
# $$ w_x = 2x(y+1) \quad\quad\text{and}\quad\quad w_y = x^2$$

# %% [markdown]
# $$ P_1(x,y) = P_1(\mathbf{x}) = 1 + w_x(\mathbf{a})(x-1) + w_y(\mathbf{a})y = 1 + 2(x-1) + y $$

# %% [markdown]
# $$ P_1(\mathbf{x}) = 2x+y-1$$

# %% [markdown]
# **a)**  Whereas the coefficient of $x$ is greater than the coefficient of $y$ therefore $w$ is more sensitive to changes in $x$ around $\mathbf{a}$.

# %% [markdown]
# **b)**  $$ \Delta P_1 = 2\Delta x + \Delta y = 0$$

# %% [markdown]
# So, a two to one ratio.

# %% [markdown]
# ### Min-Max Problems

# %% [markdown]
# #### $\S\,2\mathrm{F} : 1$
#
# **a)**  The position vector of a point on the surface is:
#
# $$ \mathbf{r}:=\mathbf{r}(y,z) = \left\langle \frac{1}{yz^2}, y,z\right\rangle$$

# %% [markdown]
# And,
#
# $$ |\mathbf{r}|  = |\mathbf{r}|(y,z) = \sqrt{\frac{1}{y^2z^4} + y^2 + z^2}$$

# %% [markdown]
# Let $L:=L(y,z):=|\mathbf{r}|$.  The first partial derivatives of the above function are:
#
# $$ L_y = 0.5\,\frac{2y + f_y(y,z)}{L} \quad\quad\text{where }f(y,z) = \frac{1}{y^2z^4}$$

# %% [markdown]
# $$ f_y(y,z) = -2\,\frac{1}{y^3z^4}$$

# %% [markdown]
# $$ y - \frac{1}{y^3z^4} = \frac{(yz)^4-1}{y^3z^4}$$

# %% [markdown]
# Thus,
#
# $$ L_y = \frac{(yz)^4-1}{y^3z^4L}$$

# %% [markdown]
# Taking the hint, let $S:=|\mathbf{r}|^2$.
#
# \begin{equation}\tag{1.1}
#     S_y = 2y -\frac{2}{y^3z^4} = 2\,\frac{(yz)^4-1}{y^3z^4}
# \end{equation}

# %% [markdown]
# $$ S_z = 2z + f_z(y,z)$$

# %% [markdown]
# $$ f_z = -\frac{4}{y^2z^5}$$

# %% [markdown]
# Thus,
#
# \begin{equation}\tag{1.2}
#     S_z = \frac{2y^2z^6-4}{y^2z^5}
# \end{equation}

# %% [markdown]
# $$ = 2\,\frac{y^2z^6-2}{y^2z^5}$$

# %% [markdown]
# The second partial derivaives of $S$ are:
#
# $$ S_{yy} = 2\left(\frac{4y^3z^4}{y^3z^4} - 3\,\frac{(yz)^4-1}{(yz)^4}\right) = 2\,\frac{4(yz)^4 - 3(yz)^4 + 3}{(yz)^4}$$

# %% [markdown]
# \begin{equation}\tag{1.6a}
#     S_{yy} = 2\,\frac{(yz)^4+3}{(yz)^4}
# \end{equation}

# %% [markdown]
# And,
#
# $$ S_{yz} = S_{zy} = 2\left(\frac{4y^4z^3}{y^3z^4} - 4\,\frac{(yz)^4-1}{y^3z^5}\right)$$

# %% [markdown]
# \begin{equation}\tag{1.6b}
#     S_{yz} = \frac{8}{y^3z^5}
# \end{equation}

# %% [markdown]
# And, finally,
#
# $$ S_{zz} = 2\left(\frac{6y^2z^5}{y^2z^5} - 5\,\frac{y^2z^6-2}{y^2z^6}\right)$$

# %% [markdown]
# \begin{equation}\tag{1.6c}
#     S_{zz} = 2\,\frac{y^2z^6+ 10}{y^2z^6}
# \end{equation}

# %%
def S_zz(y,z):
    return 2*(y**2*z**6+10)/(y**2*z**6)
def S_yz(y,z):
    return 8/(y**3*z**5)
def S_yy(y,z):
    return 2*((y*z)**4+3)/((y*z)**4)

# %% [markdown]
# Now, to find the minimum $S$, we shall find $y$ and $z$ such that $S_z,S_y=0$.  Via equation (1.2),
#
# $$ z^6y^2 = 2 \quad\implies\quad yz^3 = \pm\sqrt{2} \quad\implies$$

# %% [markdown]
# \begin{equation}\tag{1.3}
#     y = \pm\frac{\sqrt{2}}{z^3}
# \end{equation}

# %% [markdown]
# Via the above equation, equation (1.1), the constraint that $S_y=0$, and substitution,
#
# $$ (yz)^4 = 1$$

# %% [markdown]
# \begin{equation}\tag{1.4}
#     \frac{4}{z^8} = 1\quad\implies z = \pm\sqrt[4]{2}
# \end{equation}

# %% [markdown]
# And, via the above, and equation (1.3) and substitution,
#
# \begin{equation}\tag{1.5}
#     y = \pm\frac{\sqrt{2}}{\sqrt[4]{8}} = \pm\sqrt[4]{0.5}
# \end{equation}

# %% [markdown]
# So, the critical points are:
#
# $$ \mathbf{A} = \big\{\big(\sqrt[4]{0.5},\sqrt[4]{2}\big), \big(-\sqrt[4]{0.5},\sqrt[4]{2}\big), \big(\sqrt[4]{0.5},-\sqrt[4]{2}\big), -\mathbf{a_1} \big\}$$

# %% [markdown]
# Is $\mathbf{a_1}=\big(\sqrt[4]{0.5},\sqrt[4]{2}\big)$ a minimum or maximum or neither?

# %%
A_1 = S_yy(0.5**(1/4),2**(1/4)); A_1
# Out:
# 8.000000000000004

# %%
a_1 = (0.5**(0.25), 2**(0.25)); a_2 = (-a_1[0],a_1[1]); a_3 = (a_1[0],-a_1[1]); a_4= (-a_1[0],-a_1[1])

# %%
[a_1,a_2,a_3,a_4]
# Out:
# [(0.8408964152537145, 1.189207115002721),
#  (-0.8408964152537145, 1.189207115002721),
#  (0.8408964152537145, -1.189207115002721),
#  (-0.8408964152537145, -1.189207115002721)]

# %%
B_1 = S_yz(*a_1); C_1 = S_zz(*a_1)
A_1*C_1 > B_1**2
# Out:
# True

# %%
(A_1*C_1, B_1**2)
# Out:
# (96.00000000000007, 32.00000000000002)

# %% [markdown]
# Is $\mathbf{a_2}$ a min or max or neither?

# %%
A_2 = S_yy(*a_2); B_2 = S_yz(*a_2); C_2 = S_zz(*a_2)
A_2*C_2 > B_2**2
# Out:
# True

# %%
(A_2*C_2,B_2**2)
# Out:
# (96.00000000000007, 32.00000000000002)

# %% [markdown]
# Is $\mathbf{a_3}$ a min, max, or neither?

# %%
A_3 = S_yy(*a_3); B_3 = S_yz(*a_3); C_3 = S_zz(*a_3)
A_3*C_3 > B_3**2
# Out:
# True

# %%
A_3
# Out:
# 8.000000000000004

# %% [markdown]
# Finally, is $\mathbf{a_4}$ a min, max, or neither?

# %%
A_4 = S_yy(*a_4); B_4 = S_yz(*a_4); C_4 = S_zz(*a_4)
A_4*C_4 > B_4**2
# Out:
# True

# %%
A_4
# Out:
# 8.000000000000004

# %% [markdown]
# **b)**
#
# $$ z = \frac{x^2-1}{y}$$

# %% [markdown]
# The distance from the origin to a point $(x,y,z)$ on the surface given by the above equation is equal to the magnitude of $\mathbf{r}$, where:
#
# $$ \mathbf{r}:=\mathbf{r}(t) = \left\langle x,y,\frac{x^2-1}{y}\right\rangle$$

# %% [markdown]
# $$ S := |\mathbf{r}|^2 = x^2 + y^2 + \frac{\big(x^2-1\big)^2}{y^2}$$

# %% [markdown]
# Note that $S$ is not differentiable when $y=0$.

# %% [markdown]
# $$ S_y = 2y - 2\,\frac{\big(x^2-1\big)^2}{y^3} \quad\quad\text{and}\quad\quad S_x = 2x + 4x\,\frac{x^2-1}{y^2}$$

# %% [markdown]
# To find the critical points of $S$ we shall find $x$ and $y$ such that $S_y,S_x=0$.
#
# $$ y^4 = \big(x^2-1\big)^2 \quad\quad\text{and}\quad\quad 0.5y^2 = 1-x^2$$

# %% [markdown]
# $$ \pm y^2 = x^2-1 \quad\quad\text{and}\quad\quad y^2 = 2\big(1-x^2\big)$$

# %% [markdown]
# $$ \pm 2\big(1-x^2\big) = x^2-1$$

# %% [markdown]
# $$ \implies\quad -1\cdot \pm 2x^2 - x^2 = -1 \pm 2$$

# %% [markdown]
# $$ \implies\quad x^2\big(\pm 2 - 1\big) = \pm 2 - 1 \quad\implies$$

# %% [markdown]
# \begin{equation}\tag{1.1}
#     x = \pm 1
# \end{equation}

# %% [markdown]
# #### $\S\,2\mathrm{F} : 2$

# %% [markdown]
# #### $\S\,2\mathrm{F} : 5$

# %% [markdown]
# The volume of the drawer is given by:
#
# $$ V = xyz = 2.5$$

# %% [markdown]
# The total cost is given by:
#
# $$ T = xy + xz + 4yz + 4xz = xy + 4yz + 5xz$$

# %% [markdown]
# $$ T = \frac{5}{2z} + \frac{10}{x} + 5xz$$

# %% [markdown]
# $$ T_x = 5z - \frac{10}{x^2} \quad\quad\text{and}\quad\quad T_z = 5x - \frac{5}{2z^2}$$

# %% [markdown]
# Now, must find $x$ and $z$ such that $T_x,T_z=0$.
#
# $$ z = \frac{2}{x^2} \quad\quad\text{and}\quad\quad x = \frac{1}{2z^2}$$

# %% [markdown]
# $$ z = 8z^4 \quad\implies\quad z^3 = \frac{1}{8} \quad\implies$$

# %% [markdown]
# \begin{equation}\tag{5.1}
#     z = 0.5 \quad\quad\text{and}\quad\quad x = 2
# \end{equation}

# %% [markdown]
# $$ y = \frac{5}{2zx} = 2.5$$

# %% [markdown]
# #### $\S\,2\mathrm{G} : 1$
#
# **a)**  $$ D_a = -2\sum_{i=1}^3\big(y_i - (ax_i + b)\big)x_i$$

# %% [markdown]
# $$ D_b = -2\sum_{i=1}^3\big(y_i-(ax_i+b)\big)$$

# %% [markdown]
# We must find $a$ and $b$ such that $D_a,D_b=0$.
#
# $$ \sum_{i=1}^3x_iy_i - a\sum_{i=1}^3x_i^2 - b\sum_{i=1}^3 x_i = 0$$

# %% [markdown]
# $$ \sum_{i=1}^3 y_i - a\sum_{i=1}^3x_i - 3b = 0$$

# %% [markdown]
# Dividing throughout both of the above equation by $3$ gives:
#
# $$ \frac{1}{3}\sum_{i=1}^3x_iy_i - a\bar{s} - b\bar{x} = 0$$

# %% [markdown]
# $$ \bar{y} - a\bar{x} - b = 0$$

# %% [markdown]
# where $\bar{x}$, $\bar{y}$, and $\bar{s}$ denote the average value of $x_i$, $y_i$ and $x_i^2$ respectively.

# %% [markdown]
# \begin{equation}\tag{1.1}
#     b = \bar{y}-a\bar{x}
# \end{equation}

# %% [markdown]
# $$ \frac{1}{3}\sum_{i=1}^3x_iy_i - a\bar{s} - \bar{x}\big(\bar{y}-a\bar{x}\big) = 0$$

# %% [markdown]
# $$ \frac{1}{3}\sum_{i=1}^3x_iy_i - \bar{x}\bar{y} = a\bar{s} - a\bar{x}^2$$

# %% [markdown]
# \begin{equation}\tag{1.2a}
#     a = \frac{1 - \bar{x}\bar{y}}{\bar{s} - \bar{x}^2}
# \end{equation}

# %% [markdown]
# $$ \bar{x}\bar{y} = \frac{1}{3}\cdot\frac{5}{3} = \frac{5}{9} \quad\quad 1 - \frac{5}{9} = \frac{4}{9}$$

# %% [markdown]
# $$ \bar{s} = \frac{1}{3} \quad\quad \bar{s}-\bar{x}^2 = \frac{2}{9}$$

# %% [markdown]
# Finally,
#
# \begin{equation}\tag{1.2}
#     a = 2
# \end{equation}

# %% [markdown]
# Via equations (1.1) and (1.2) and substitution,
#
# $$ b = \frac{5}{3} - \frac{2}{3} = 1$$

# %%
x = np.linspace(0,1,num=3)
f = 2*x + 1

fig, ax = plt.subplots()
ax.set_title('Linear Interpolation', size=13)
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.grid()

ax.plot([0,0,1],[0,2,3],'.')
ax.plot(x,f)

# %% [markdown]
# **b)**  $$ \bar{x} = 1 \quad\quad \bar{y} = 1 = \bar{x} \quad\quad \bar{s} = \frac{5}{3}$$

# %% [markdown]
# $$ \bar{p} = \frac{1}{3}\sum_{i=1}^3x_iy_i = \frac{4}{3}$$

# %% [markdown]
# $$ a = \frac{1}{3}\cdot \frac{3}{2} = 0.5$$

# %% [markdown]
# $$ b = 1 - a = 0.5$$

# %%
x = np.linspace(0,2,num=3)
f = 0.5*x + 0.5

fig, ax = plt.subplots()
ax.grid()

ax.plot([0,1,2],[0,2,1],'.')
ax.plot(x,f)

# %% [markdown]
# **c)**  $$ \bar{x} = 2 \quad\quad \bar{y} = 2 \quad\quad \bar{s} = \frac{14}{3} \quad\quad\bar{p} = \frac{13}{3}$$

# %% [markdown]
# $$ a = \frac{1}{3}\cdot \frac{3}{2} = 0.5$$

# %% [markdown]
# $$ b = 2 - 1 = 1$$

# %%
x = np.linspace(0,3,num=20)
f = 0.5*x + 1

fig, ax = plt.subplots()

ax.plot([1,2,3],[1,3,2],'.')
ax.plot(x,f)

# %% [markdown]
# #### $\S\,2\mathrm{G} : 4$

# %% [markdown]
# $$ D = \sum_{i=1}^n \big(z_i - (a+bx_i + cy_i)\big)^2$$

# %% [markdown]
# $$ D_a = -2\sum_{i=1}^n\big(z_i-(a+bx_i + cy_i) \big)$$

# %% [markdown]
# $$ D_b = -2\sum_{i=1}^n\big(z_i-(a+bx_i + cy_i)\big)x_i$$

# %% [markdown]
# $$ D_c = -2\sum_{i=1}^n\big(z_i-(a+bx_i + cy_i)\big)y_i$$

# %% [markdown]
# We must find $a$, $b$, and $c$ such that $D_a, D_b, D_c=0$.  Dividing throughout the three obtained equations by $-2n$ gives:
#
# $$ \bar{z} = a + b\bar{x} + c\bar{y}$$

# %% [markdown]
# $$ \overline{zx} = a\bar{x} + b\bar{s} + c\overline{xy}$$

# %% [markdown]
# $$ \overline{zy} = a\bar{y} + b\overline{xy} + c\bar{y^2}$$

# %% [markdown]
# #### $\S\,2\mathrm{H} : 1$
#
# **a)**  $$ z_x = 2x - y - 3 \quad\quad \text{and}\quad\quad z_y = -4y - x - 3$$

# %% [markdown]
# \begin{equation}\tag{1.1}
#     x = -4y - 3
# \end{equation}

# %% [markdown]
# $$ y = 2x - 3 = -8y - 6 - 3 \quad\implies\quad 9y = -9 \quad\implies$$

# %% [markdown]
# \begin{equation}\tag{1.2}
#     y = -1
# \end{equation}

# %% [markdown]
# Via equations (1.2) and (1.1) and substitution,
#
# \begin{equation}\tag{1.3}
#     x = 4-3 = 1
# \end{equation}

# %% [markdown]
# And, via equations (1.2) and (1.3) are critical point is:
#
# \begin{equation}\tag{1.4}
#     \mathbf{a} = (1,-1)
# \end{equation}

# %% [markdown]
# The second partial derivatives of $z$ are:
#
# $$z_{xx} = 2 \quad\quad z_{xy} = -1 \quad\quad z_{yy} = -4 $$

# %% [markdown]
# Whereas $AC < B^2$ therefore $\mathbf{a}$ is a saddle point.

# %% [markdown]
# **b)**  $$ z_x = 6x + y - 1 \quad\quad\text{and}\quad\quad z_y = x + 2y - 2$$

# %% [markdown]
# $$ y = 1-6x \quad\quad\text{and}\quad\quad x = 2-2y$$

# %% [markdown]
# $$ x = 2-2+12x \quad\implies \quad x=0$$

# %% [markdown]
# $$ y = 1$$

# %% [markdown]
# Thus, our critical point is $\mathbf{a} = (0,1)$.  Now, the second partial derivatives of $z$ are:
#
# $$ z_{xx} = 6 \quad\quad z_{xy} = 1 \quad\quad z_{yy} = 2$$

# %% [markdown]
# Whereas $AC>B^2$ and $A>0$ therefore $\mathbf{a}$ is a minimum point.

# %% [markdown]
# **c)**  $$ z_x = 8x^3 - y \quad\quad\text{and}\quad\quad z_y= 2y - x$$

# %% [markdown]
# $$ y = 8x^3 \quad\quad\text{and}\quad\quad x = 2y$$

# %% [markdown]
# $$ 1 = 16x^2 \quad \implies\quad x = \pm\frac{1}{4} = \pm0.25$$

# %% [markdown]
# $$ y = \pm\frac{2^3}{4^3} = \pm (0.5)^3 = \pm \frac{1}{8}$$

# %% [markdown]
# Thus, our critical points are:
#
# $$ \mathbf{a_1} = 0.25(1,0.5) \quad\quad\text{and}\quad\quad \mathbf{a_2} = -\mathbf{a_1}$$

# %% [markdown]
# The second derivatives of $z$ are:
#
# $$ z_{xx} = 24x^2 \quad\quad z_{xy} = 0 \quad\quad z_{yy} = 2$$

# %% [markdown]
# Both critical points are a minimum.

# %% [markdown]
# **d)**
#
# $$ z_x = 3x^2 - 3y \quad\quad\text{and}\quad\quad z_y = 3y^2 - 3x$$

# %% [markdown]
# $$ y = x^2 \quad\quad\text{and}\quad\quad x = y^2$$

# %% [markdown]
# $$ y^3 = 1 \quad\implies\quad y = 1$$

# %% [markdown]
# Thus $\mathbf{a}=(1,1)$.
#
# $$ z_{xx} = 6x \quad\quad z_{xy} = -3 \quad\quad z_{yy} = 6y$$

# %% [markdown]
# The critical point is a minimum.

# %% [markdown]
# **e)**  $$ z_x = 3x^2\big(y^3+1\big)\quad\quad\text{and}\quad\quad z_y = 3y^2\big(x^3+1\big)$$

# %% [markdown]
# One critical point is:
#
# $$ \mathbf{a_1} = (0,0)$$

# %% [markdown]
# $$ y = 1 \quad\quad\text{and}\quad\quad x = 1$$

# %% [markdown]
# Thus, another critical point is:
#
# $$ \mathbf{a_2} = (1,1)$$

# %% [markdown]
# $$ z_{xx} = 6x\big(y^3+1\big) \quad\quad z_{xy} = 9(xy)^2 \quad\quad z_{yy} = 6y\big(x^3+1\big)$$

# %% [markdown]
# The second derivative test fails for $\mathbf{a_1}$.

# %% [markdown]
# $$ A_2 = 12 \quad\quad B_2 = 9 \quad\quad C_2 = 12$$

# %% [markdown]
# $\mathbf{a_2}$ is a minimum.

# %% [markdown]
# #### $\S\,2\mathrm{H} : 3$
#
# $$ f_x = 2x + 2 \quad\quad\text{and}\quad\quad f_y = 2y + 4$$

# %% [markdown]
# $$ x=-1\quad\quad y = -2$$

# %% [markdown]
# The critical point $(-1,-2)$ is a minimum, but, it exists in the left half-plane.  The maximum exists at $(\infty,\infty)$.  To find the min in $R$, we shall find the min of
#
# $$g(x):= f(x,-x) = 2x^2 -2x - 1$$

# %% [markdown]
# $$ g'(x) = 4x - 2 \quad\implies\quad x = 0.5$$

# %% [markdown]
# The minimum in $R$ is thus,
#
# $$ f(0.5,-0.5) = 0.5 + 1 - 2 - 1 = -1.5$$

# %% [markdown]
# $$ \Delta z = \int_{0.5}^x f_x \,\partial x + \int_{-0.5}^y f_y\,\partial y$$

# %% [markdown]
# $$ = x^2 + 2x - 0.25 - 1 + y^2 + 4y - 0.25 + 2 = x^2+2x + y^2 + 4y + 0.5$$

# %% [markdown]
# If there exists a point $(x,-x)$ such that:
#
# \begin{equation}\tag{1.1}
#     \Delta z < 0 \quad\quad\text{where } y > -x
# \end{equation}

# %% [markdown]
# then $(0.5,-0.5,-1.5)$ is *not* the minimum point in $R$.

# %% [markdown]
# $$ y^2 + 4y + 0.5 + x^2 + 2x < 0$$

# %% [markdown]
# $$ 2y^2 + 8y + 1 + 2x^2 + 4x < 0$$

# %% [markdown]
# Via the above inequality and the quadratic formula,
#
# \begin{equation}\tag{1.2}
#     y < \frac{-8\pm\sqrt{16\cdot 4 - 16x\big(x+2\big)}}{4} = -2\pm\sqrt{4-x^2-2x}
# \end{equation}

# %% [markdown]
# Via the above inequality and the caveat to inequality (1.1),
#
# $$ -x < -2\pm\sqrt{4-x^2-2x}$$

# %% [markdown]
# $$ (2-x)^2 = x^2 - 4x + 4 < 4-x^2-2x$$

# %% [markdown]
# $$ 2x^2 - 2x < 0 \quad\implies\quad x - 1 < 0 \quad\implies $$

# %% [markdown]
# $$ x < 1$$

# %% [markdown]
# $$ -y < x < 1 \quad \implies \quad y > -1 $$

# %% [markdown]
# #### $\S\,2\mathrm{H} : 4$
#
# Find the maximum and minimum points of the function $xy − x − y + 2$ on
#
# **a)** the first quadrant **b)** the square $R$ : $0 \le x \le 2$, $0 \le y \le 2$;
# (study its values at the unique critical point and on the boundary lines) point.
# **c)** use the data to guess the critical point type, and confirm it by the second derivative
# test.

# %% [markdown]
# $$ f(x,y) := z = xy-x-y+2 \quad\quad z_x = y - 1 \quad\quad z_y = x - 1$$
#
# The critical point of $f(x,y)$ is $(1,1)$, which is a saddle point.

# %% [markdown]
# **a)**  The min on the first quadrant exists at both $(\epsilon_x,\infty)$ and $(\infty,\epsilon_y)$, where $\epsilon_x$ and $\epsilon_y$ are the epsilon values of the $x$ and $y$ domain respectively.  Note that the epsilon of a continuous domain is infinitismal.

# %% [markdown]
# The max exists at $(\infty,\infty)$.

# %% [markdown]
# $$ x > 0 \quad\quad\text{and}\quad\quad y>0$$

# %% [markdown]
# $$ x(y-1) - y = z-2 \quad\implies\quad x = \frac{z-2+y}{y-1}$$

# %% [markdown]
# $$ z-2+ y > 0 \quad\implies \quad y > 2-z$$

# %% [markdown]
# **b)**  The mins exists at $(0,2,0)$ and $(2,0,0)$ and the max exists at $(2,2,2)$ and $(0,0,2)$.
#
# $$ g(x):=f(x,0) = 2-x \quad\quad\max g = 2_{\big| x\ge 0}$$

# %% [markdown]
# $$ g(y):=f(0,y) = 2-y \quad\quad \max g = 2_{\big|y\ge 0}$$

# %% [markdown]
# $$ g(x):=f(x,2) = 2x - x = x \quad\quad \max g = 2_{\big| 0\le x \le 2}$$

# %% [markdown]
# #### $\S\,2\mathrm{H} : 6$
#
# **a)** Two wires of length $4$ are cut in the same way into three pieces, of length $x$, $y$
# and $z$; the four $x$, $y$ pieces are used as the four sides of a rectangle; the two $z$ pieces are bent
# at the middle and joined at the ends to make a square of side $z/2$. Find the rectangle and
# square made this way which together have the largest and the smallest total area.
# Using the answer, tell what type the critical point is.

# %% [markdown]
# \begin{equation}\tag{6.1}
#     x + y + z = 4
# \end{equation}

# %% [markdown]
# The area of the rectangle $R$ and square $S$ are given by:
#
# $$ R = xy \quad\quad\text{and}\quad\quad S = 0.25z^2$$

# %% [markdown]
# The combined area of our square and rectangle is given by:
#
# \begin{equation}\tag{6.2}
#     T = R+S = xy + 0.25z^2
# \end{equation}

# %% [markdown]
# $$ = xy + 0.25(4 - x- y)^2$$

# %% [markdown]
# $$ = xy + 0.25\big(x^2+y^2+16 -8x -8y + 2xy\big) = xy + 0.25x^2 + 0.25y^2 + 4 - 2x - 2y + 0.5xy$$

# %% [markdown]
# \begin{equation}\tag{6.2}
#     T = 0.25x^2+0.25y^2 + 1.5xy -2x - 2y + 4
# \end{equation}

# %%
x, y = sp.symbols('x y')
T = 0.25*x**2 + 0.25*y**2 + 1.5*x*y - 2*x - 2*y + 4; T
# Out:
# 0.25*x**2 + 1.5*x*y - 2*x + 0.25*y**2 - 2*y + 4

# %%
x = np.linspace(-1,4,num=50)
y = np.linspace(-1,4,num=50)
x, y = np.meshgrid(x,y)
t = np.linspace(0,4,num=25)
f = 4 - t
T = 0.25*x**2 + 0.25*y**2 + 1.5*x*y - 2*x - 2*y + 4

fig, ax = plt.subplots()
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.grid()

cs = ax.contour(x,y,T,levels=np.linspace(-1,5,num=12))
# Plot big triangle.
ax.plot(t,f,[0 for i in range(10)],np.linspace(0,4,num=10),np.linspace(0,4,num=10),[0 for i in range (10)],color='b',ls='--')
# Plot small triangle.
xx = np.linspace(1,3,num=10)
ax.plot(xx,[1 for i in range(10)],[1 for i in range(10)],xx,xx,4-xx,color='orange',ls='--')
ax.plot([1],[1],'r')
ax.annotate(r'$\mathbf{a}$',(1,1))
cb = fig.colorbar(cs)

# %% [markdown]
# The first partial derivatives of $T$ are:
#
# $$ T_x = 0.5x + 1.5y - 2 \quad\quad\text{and}\quad\quad T_y = 0.5y + 1.5x - 2$$

# %%
T_x = 0.5*x + 1.5*y - 2; T_y = 0.5*y + 1.5*x - 2

# %% [markdown]
# Note that:
#
# \begin{equation}\tag{6.1}
#     \text{a: }\;0 < x,y,z < 4  \quad\quad\text{and}\quad\quad \text{b: }\;0 < 4 - x - y < 4
# \end{equation}

# %% [markdown]
# \begin{equation}\tag{6.1b}
#     x + y < 4
# \end{equation}

# %% [markdown]
# With the caveat that $x,y>0$, $T>0$.

# %% [markdown]
# Our task is to find the min an max value(s) of $T$ on the triangle bounded by $x>0$, $y>0$ and the line given by $y = 4-x$, which is shaded in blue in the above figure containing a contour plot of $T$.  To put in another way, the triangle $\overline{PQR}$, where
#
# $$ P = (0,0,0) \quad\quad Q = (0,4,0) \quad\quad R = (4,0,0)$$

# %% [markdown]
# The critical point of $T$, denoted as $\mathbf{a}$, is given by:
#
# $$ a_x + 3a_yy = 4 \quad\implies\quad a_x = 4-3a_y$$

# %% [markdown]
# and,
#
# $$ a_y + 3a_x = 4 \quad \implies\quad a_y = 4-3a_x$$

# %% [markdown]
# $$ a_y = 4 - 12 + 9a_y \quad\implies\quad -8a_y = -8 \quad\implies$$

# %% [markdown]
# \begin{equation}\tag{6.3}
#     a_y = 1 \quad\quad \text{and}\quad\quad a_x = 1 \quad\implies\quad \mathbf{a} = (1,1)
# \end{equation}

# %% [markdown]
# $$ T_x(x,1) = 0.5x - 0.5 = 0.5(x-1) \quad\quad\text{and}\quad\quad T_y(1,y) = 0.5(y-1)$$

# %% [markdown]
# For $x > 1$ and $1 < y < 4-x$, $T(x,y) > T(1,1)$, or, on the triangle colored in orange in the above figure, $\Delta T = T - T_0 = T - T(1,1) > 0$.
#
# $$ T(x,y) > T(1,1) \quad\text{for }\, x> 1 \,\land\, 1< y < 4-x$$

# %% [markdown]
# And, for $ 0 < x < 1$ and $0 < y < 1$, $\Delta T > 0$.
#
# $$ T(x,y) > T(1,1) \quad\text{for }\, 0 < x < 1 \,\land\,0<y<1$$

# %% [markdown]
# To find the max and min of $T$ on the hypotenuse of the blue triangle, first, let $f(x)$ be defined as:
#
# $$ f(x) :=  T(x,4-x) = 4x-x^2 = x(4-x) \quad\quad\text{where } 0 < x < 4$$

# %%
f = T.subs(y,4-x); f.expand()
# Out:
# -1.0*x**2 + 4.0*x

# %% [markdown]
# $$ f'(x) = 4-2x = 2(2-x)$$

# %% [markdown]
# Next, we will find the critical point of $f(x)$, denoted as '$\mathbf{b}$', by finding $b_x$ such that $f'(b_x)=0$.
#
# $$ b_x = 2 \quad\quad b_y = f(b_x) = 4$$

# %% [markdown]
# So, $f_\max = b_y$.  Now the min value of $f(x)$, which is equal to the min value of $T$ on the aforementioned hypotenuse, is given by:
#
# $$ f_\min = f(\epsilon) = f(4-\epsilon) \approxeq 0$$

# %% [markdown]
# On the square defined by $S$ : $0 < x < 1$ and $0 < y < 1$, $\Delta T > 0$.  The max value of $T$ on this square is $T(\epsilon,\epsilon)\approxeq 4$.

# %% [markdown]
# To find the max and min values of $T$ on the edge of the blue triangle defined by $0<y<4$ and $x=0$, first let $g(y)$ be defined as:
#
# $$ g(y) := T(0,y) = 0.25y^2 - 2y + 4 \quad\quad\text{where } 0<y<4$$

# %% [markdown]
# $$ g'(y) = 0.5y - 2$$

# %% [markdown]
# $$ g'(c_y)=0 \quad\implies\quad c_y = 4$$

# %% [markdown]
# $$ g_\min = g(c_y) = $$

# %% [markdown]
# The maximum area exists at $(2-\epsilon, 2-\epsilon, 2\epsilon)$ and is given by:
#
# $$ T_\max \approxeq 4$$

# %% [markdown]
# $$ T_\min \approxeq 0$$

# %% [markdown]
# **b)** Confirm the critical point type by using the second derivative test.

# %% [markdown]
# The second partial derivatives of $T$ are:
#
# $$ T_{xx} = 0.5 \quad\quad T_{xy} = 1.5 \quad\quad T_{yy} = 0.5$$

# %% [markdown]
# Whereas $T_{xx}T_{yy}<T_{yx}^2$ therefore $\mathbf{a}$ is a saddle point.

# %% [markdown]
# #### $\S\,2\mathrm{H} : 7$
# **a)** Find the maximum and minimum points of the function $2x^2 − 2xy + y^2 − 2x$
# on the rectangle $R$ : $0 \le x \le 2$; $−1 \le y \le 2$; using this information, determine the type of
# the critical point.

# %% [markdown]
# $$ f(x,y) := z = 2x^2 - 2xy + y^2 -2x$$

# %%
x = np.linspace(-1,3,num=50)
y = np.linspace(-2,3,num=50)
x,y = np.meshgrid(x,y)

z = 2*x**2 - 2*x*y + y**2 - 2*x

fig, ax = plt.subplots()
ax.grid()
cs = ax.contour(x,y,z, levels = 12)
cb = fig.colorbar(cs)

# %% [markdown]
# The first partial derivatives of $f(x,y)$ are:
#
# $$ z_x = 4x - 2y - 2 = 2(2x-y-1)\quad\quad\text{and}\quad\quad z_y = 2y - 2x = 2(y-x) $$

# %% [markdown]
# To find the critical point $\mathbf{a}$, we shall find $a_x,a_y$ such that $z_x,z_y=0$.
#
# $$ a_y=a_x \quad\quad\text{and}\quad\quad 2a_x - a_x = a_x = 1 $$

# %% [markdown]
# Thus,
#
# $$ \mathbf{a} = (1,1)$$

# %% [markdown]
# $$ f(1,1) = -1 \quad \quad f_x(x,1) = 4(x - 1) \quad\quad f_y(1,y) = 2(y-1)$$

# %% [markdown]
# $$ f_x(x,1) > 0_{\,\big| x \,> \,1 = a_x}\quad\quad\text{and}\quad\quad f_y(1,y) > 0 _{\,\big| y \,>\,1 = a_y}$$

# %% [markdown]
# The above two inequalities imply that, as we move away from $\mathbf{a}$ in the positive or negative direction along the $x$ or $y$ axis, $\Delta z > 0$, where $\Delta z = z - z(1,1) = z + 1$.  Ultimately $z > -1 = f(1,1)$ under the aforementioned conditions.

# %% [markdown]
# Now, to find the min and max values of $f$ on the edges of $R$, first let $g(x)$ be defined as:
#
# $$ g(x) := f(x,-1) = 2x^2+1 \quad\quad\text{where } 0\le x \le 2$$

# %% [markdown]
# $$ g_\min = g(0) = 1 \quad\quad\text{and}\quad\quad g_\max = g(2) = 9$$

# %% [markdown]
# Now, let $h(x)$ be defined as:
#
# $$ h(x) := f(x,2) = 2x^2 - 6x + 4 \quad\quad\text{where } 0\le x \le 2$$

# %% [markdown]
# $$ h'(x) = 4x - 6 \quad\quad h_\min = h(1.5) = -0.5 \quad\quad h_\max = h(0) = 4$$

# %% [markdown]
# Let $H(y)$ be defined as:
#
# $$ H(y):=f(0,y) = y^2 \quad\quad\text{where }-1\le y\le2$$

# %% [markdown]
# $$ H_\min = H(0) = 0 \quad\quad\text{and}\quad\quad H_\max = H(2) = 4$$

# %% [markdown]
# Let $G(y)$ be defined as:
#
# $$ G(y) := f(2,y) = y^2 - 4y + 4 = (y - 2)^2$$

# %% [markdown]
# $$ G'(y) = 2y - 4 \quad\quad G_\min = G(2) = 0 \quad\quad G_\max = G(-1) = 9$$

# %% [markdown]
# Finally,
#
# $$ f_\max = 9 \quad\quad \text{and}\quad\quad f_\min = -1$$

# %% [markdown]
# Whereas no point on the edge of $R$ is a less than or equal to $f(\mathbf{a})$ therefore $\mathbf{a}$ is a minimum.

# %% [markdown]
# **b)** Confirm the critical point type by using the second derivative test

# %% [markdown]
# $$ f_{xx} = 4 \quad\quad f_{xy} = 0 \quad\quad f_{yy} = 2$$

# %% [markdown]
# Whereas $8>0$ and $4>0$ therefore $\mathbf{a}$ is a minimum.
